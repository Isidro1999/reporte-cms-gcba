# %%
import pandas as pd 
df = pd.read_csv("materiales.csv", sep=";")
df.head()
len(df)
# Out:
# 28731

# %%
df["Fecha de creación"] = pd.to_datetime(df["Fecha de creación"], errors="coerce")

# %%
df_2y = df[df["Fecha de creación"] >= "2023-01-01"] ## no tenemos mas materiales pero filtro por las dudas los dos ultimos años
len(df_2y)
# Out:
# 28731

# %%
df_2y["Tags"].head(20)
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     Material - Foto, Material - Foto y Video, Eje ...
# 9     Material - Foto, Material - Foto y Video, Eje ...
# 10    Crudos - Selección, Material - Foto, Material ...
# 11    Crudos - Selección, Material - Foto, Material ...
# 12    Material - Foto y Video, Material - Video, Eje...
# 13    Material - Foto y Video, Material - Video, Eje...
# 14    Material - Foto y Video, Material - Video, Eje...
# 15    Material - Foto y Video, Material - Video, Eje...
# 16    Material - Foto y Video, Material - Video, Eje...
# 17    Material - Foto y Video, Material - Video, Eje...
# 18    Material - Foto, Material - Foto y Video, Eje ...
# 19    Material - Foto, Material - Foto y Video, Eje ...
# Name: Tags, dtype: object

# %%
df_2y["Tags"].notna().sum()
# Out:
# np.int64(28428)

# %%
df_2y["Tags_list"] = df_2y["Tags"].dropna().apply(lambda x: [t.strip() for t in x.split(",")])

# %%
df_tags = df_2y.dropna(subset=["Tags_list"]).explode("Tags_list")
df_tags.head()
# Out:
#    Material ID  Creador ID                                Nombre del material  \
# 8       929735       47254  Hospitales - Hospital Santojanni - Tomógrafo -...
# 8       929735       47254  Hospitales - Hospital Santojanni - Tomógrafo -...
# 8       929735       47254  Hospitales - Hospital Santojanni - Tomógrafo -...
# 8       929735       47254  Hospitales - Hospital Santojanni - Tomógrafo -...
# 8       929735       47254  Hospitales - Hospital Santojanni - Tomógrafo -...
#
#   Nombre del creador    Estado   Categoria Tipo de material  \
# 8              Salud  Activado  Coberturas           Imagen
# 8              Salud  Activado  Coberturas           Imagen
# 8              Salud  Activado  Coberturas           Imagen
# 8              Salud  Activado  Coberturas           Imagen
# 8              Salud  Activado  Coberturas           Imagen
#
#     Fecha de creación                                               Tags  \
# 8 2025-11-27 16:02:50  Material - Foto, Material - Foto y Video, Eje ...
# 8 2025-11-27 16:02:50  Material - Foto, Material - Foto y Video, Eje ...
# 8 2025-11-27 16:02:50  Material - Foto, Material - Foto y Video, Eje ...
# 8 2025-11-27 16:02:50  Material - Foto, Material - Foto y Video, Eje ...
# 8 2025-11-27 16:02:50  Material - Foto, Material - Foto y Video, Eje ...
#
#                                      URL del archivo  \
# 8  https://cdn.feater.me/files/images/9473491/16e...
# 8  https://cdn.feater.me/files/images/9473491/16e...
# 8  https://cdn.feater.me/files/images/9473491/16e...
# 8  https://cdn.feater.me/files/images/9473491/16e...
# 8  https://cdn.feater.me/files/images/9473491/16e...
#
#                       Tags_list
# 8               Material - Foto
# 8       Material - Foto y Video
# 8  Eje - Cuidado y Bien Público
# 8               Mes - Noviembre
# 8                    Comuna - 9

# %%
df_tags[["Grupo", "Valor"]] = df_tags["Tags_list"].str.split(" - ", n=1, expand=True)

# %%
df_hierarchy = df_tags.pivot_table(
    index="Material ID",
    columns="Grupo",
    values="Valor",
    aggfunc=lambda x: ', '.join(x.dropna().unique())
).reset_index()

# %%
df_final = df_2y.merge(df_hierarchy, on="Material ID", how="left")

# %%
df_final.head(20)
# Out:
#     Material ID  Creador ID  \
# 0        929744       47254
# 1        929743       47254
# 2        929742       47254
# 3        929741       47254
# 4        929740       47254
# 5        929739       47254
# 6        929737       47254
# 7        929738       47254
# 8        929735       47254
# 9        929734       47254
# 10       929733       47254
# 11       929732       47254
# 12       929731       47254
# 13       929730       47254
# 14       929729       47254
# 15       929728       47254
# 16       929727       47254
# 17       929726       47254
# 18       928828       47254
# 19       928829       47254
#
#                                   Nombre del material Nombre del creador  \
# 0   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 1   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 2   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 3   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 4   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 5   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 6   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 7   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 8   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 9   Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 10  Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 11  Hospitales - Hospital Santojanni - Tomógrafo -...              Salud
# 12  Hospitales - Hospital Santojanni - nueva guard...              Salud
# 13  Hospitales - Hospital Santojanni - nueva guard...              Salud
# 14  Hospitales - Hospital Santojanni - nueva guard...              Salud
# 15  Hospitales - Hospital Santojanni - nueva guard...              Salud
# 16  Hospitales - Hospital Santojanni - nueva guard...              Salud
# 17  Hospitales - Hospital Santojanni - nueva guard...              Salud
# 18  Hospitales - Hospital Santojanni - nueva guard...              Salud
# 19  Hospitales - Hospital Santojanni - nueva guard...              Salud
#
#       Estado   Categoria Tipo de material   Fecha de creación  \
# 0   Activado  Coberturas            Video 2025-11-27 16:14:56
# 1   Activado  Coberturas            Video 2025-11-27 16:14:55
# 2   Activado  Coberturas            Video 2025-11-27 16:14:53
# 3   Activado  Coberturas            Video 2025-11-27 16:14:50
# 4   Activado  Coberturas            Video 2025-11-27 16:14:46
# 5   Activado  Coberturas            Video 2025-11-27 16:14:43
# 6   Activado  Coberturas            Video 2025-11-27 16:14:39
# 7   Activado  Coberturas            Video 2025-11-27 16:14:39
# 8   Activado  Coberturas           Imagen 2025-11-27 16:02:50
# 9   Activado  Coberturas           Imagen 2025-11-27 16:02:47
# 10  Activado  Coberturas           Imagen 2025-11-27 16:01:07
# 11  Activado  Coberturas           Imagen 2025-11-27 16:01:06
# 12  Activado  Coberturas            Video 2025-11-27 15:58:21
# 13  Activado  Coberturas            Video 2025-11-27 15:58:19
# 14  Activado  Coberturas            Video 2025-11-27 15:58:10
# 15  Activado  Coberturas            Video 2025-11-27 15:58:09
# 16  Activado  Coberturas            Video 2025-11-27 15:58:05
# 17  Activado  Coberturas            Video 2025-11-27 15:58:04
# 18  Activado  Coberturas           Imagen 2025-11-27 10:34:52
# 19  Activado  Coberturas           Imagen 2025-11-27 10:34:52
#
#                                                  Tags  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 
#    Seguridad Sub Eje                                            Subtema  \
# 0        NaN     NaN                                                NaN
# 1        NaN     NaN                                                NaN
# 2        NaN     NaN                                                NaN
# 3        NaN     NaN                                                NaN
# 4        NaN     NaN                                                NaN
# 5        NaN     NaN                                                NaN
# 6        NaN     NaN                                                NaN
# 7        NaN     NaN                                                NaN
# 8        NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 9        NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 10       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 11       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 12       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 13       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 14       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 15       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 16       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 17       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 18       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
# 19       NaN   Salud  Hospital General de Agudos Donación F. Santojanni
#
#           Tema
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8   Hospitales
# 9   Hospitales
# 10  Hospitales
# 11  Hospitales
# 12  Hospitales
# 13  Hospitales
# 14  Hospitales
# 15  Hospitales
# 16  Hospitales
# 17  Hospitales
# 18  Hospitales
# 19  Hospitales
#
# [20 rows x 22 columns]

# %%
df_final["Eje"].nunique()
# Out:
# 10

# %%
df_final["Eje"].value_counts().head(20) ## hay que arreglar la creacion de ejes anuevos.
# Out:
# Eje
# Encuentro                            9252
# Orden                                8202
# Cuidado y Bien Público               4667
# Obras                                4165
# Desarrollo                           1922
# Orden, Encuentro                       13
# Desarrollo, Encuentro                   6
# Cuidado y Bien Público, Encuentro       3
# Orden, Obras                            1
# Encuentro, Obras                        1
# Name: count, dtype: int64

# %%
df_final["Sub Eje"].nunique()
# Out:
# 37

# %%
df_final["Tema"].notna().sum()
# Out:
# np.int64(24091)

# %%
df_final["Tags"].isna().sum()
# Out:
# np.int64(303)

# %%
# arreglo la creacion de los ejes nuevos. Los voy a sacar y que tome unicamente la primera etiqueta
# Limpiar eje múltiple
df_final["Eje"] = df_final["Eje"].str.split(",").str[0].str.strip()
df_final["Eje"].value_counts()
# Out:
# Eje
# Encuentro                 9253
# Orden                     8216
# Cuidado y Bien Público    4670
# Obras                     4165
# Desarrollo                1928
# Name: count, dtype: int64

# %%
df_final.to_csv("data/df_final.csv", index=False)

# %%
df_final.columns
# Out:
# Index(['Material ID', 'Creador ID', 'Nombre del material',
#        'Nombre del creador', 'Estado', 'Categoria', 'Tipo de material',
#        'Fecha de creación', 'Tags', 'URL del archivo', 'Tags_list', 'Año',
#        'Comuna', 'Convivencia', 'Crudos', 'Eje', 'Material', 'Mes',
#        'Seguridad', 'Sub Eje', 'Subtema', 'Tema'],
#       dtype='object')

# %%
# arreglo sub ejes tambien

df_final["Sub Eje"] = df_final["Sub Eje"].str.split(",").str[0].str.strip()
df_final["Eje"] = df_final["Eje"].str.split(",").str[0].str.strip()
df_final["Tema"] = df_final["Tema"].astype(str).str.split(",").str[0].str.strip()
df_final["Subtema"] = df_final["Subtema"].astype(str).str.split(",").str[0].str.strip()

# %%
df_final.to_csv("data/df_final.csv", index=False)
